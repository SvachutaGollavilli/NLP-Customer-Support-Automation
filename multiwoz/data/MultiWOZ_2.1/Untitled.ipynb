# %%
import pandas as pd
import os

# %%
path = "/Users/krishnagollavilli/NLP-Customer-Support-Automation/multiwoz/data/MultiWOZ_2.1/"

# Load your cleaned dataset
df = pd.read_csv(path + "clean_multiwoz.csv")

# Filter only USER messages
df = df[df["speaker"] == "USER"].copy()

# %%
df
# Out:
#           dialogue_id speaker  \
# 0       SNG01856.json    USER
# 2       SNG01856.json    USER
# 4       SNG01856.json    USER
# 6       SNG01856.json    USER
# 8       SNG01856.json    USER
# ...               ...     ...
# 143038   MUL0501.json    USER
# 143040   MUL0501.json    USER
# 143042   MUL0501.json    USER
# 143044   MUL0501.json    USER
# 143046   MUL0501.json    USER
#
#                                             original_text  \
# 0       am looking for a place to to stay that has che...
# 2       no, i just need to make sure it's cheap. oh, a...
# 4       Yes, please. 6 people 3 nights starting on tue...
# 6                                how about only 2 nights.
# 8                         No, that will be all. Good bye.
# ...                                                   ...
# 143038  I'll be leaving from london liverpool street o...
# 143040  No, I just need the price and Train ID for the...
# 143042  Actually yes, I also want to find out what kin...
# ...

# %%
df = df.dropna(subset=["clean_text"])

# %%
df
# Out:
#           dialogue_id speaker  \
# 0       SNG01856.json    USER
# 2       SNG01856.json    USER
# 4       SNG01856.json    USER
# 6       SNG01856.json    USER
# 8       SNG01856.json    USER
# ...               ...     ...
# 143038   MUL0501.json    USER
# 143040   MUL0501.json    USER
# 143042   MUL0501.json    USER
# 143044   MUL0501.json    USER
# 143046   MUL0501.json    USER
#
#                                             original_text  \
# 0       am looking for a place to to stay that has che...
# 2       no, i just need to make sure it's cheap. oh, a...
# 4       Yes, please. 6 people 3 nights starting on tue...
# 6                                how about only 2 nights.
# 8                         No, that will be all. Good bye.
# ...                                                   ...
# 143038  I'll be leaving from london liverpool street o...
# 143040  No, I just need the price and Train ID for the...
# 143042  Actually yes, I also want to find out what kin...
# ...
